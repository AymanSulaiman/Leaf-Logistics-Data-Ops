# %% [markdown]
# # Leaf DataOps Timed Technical Assessment (75 mins)
#
# ### Scenario
#
# At a high level, Leaf's business model centers around finding predictable patterns in freight records. Thus, we ingest shipment data from a variety of external sources. As a DataOps Engineer at Leaf, you will regularly monitor that incoming data for anomalies.
#
# You've been asked to test a pipeline that ingests data via a new API integration. The API returns a JSON containing shipment data within a date range passed in the query parameters.
#
# Each key-value pair in the JSON is equivalent to the name and values, respectively, of a DataFrame column.
#
# The "columns" are:
# * the shipment `date`;
# * the distance from origin to destination (in `miles`);
# * the `price` the shipper paid to move the shipment (in USD); and
# * the `weight` of the shipment (in pounds)
#
# The cell below contains the pipeline code:

# %%
from json import loads
from functools import reduce
from math import isnan


def pipeline(*objects):
    return reduce(lambda x, fn: fn(x), objects)


def mock_api_request(url: str) -> str:
    with open("leaf_dataops.json", "r") as f:
        return f.read()


def parse_json(json: str) -> dict:
    return loads(json)

def validator(data: dict, rules: dict = None) -> tuple:
    """
    Validates a dict of data on specified logic.
    
    Args:
    - Data (dict): JSON of data with keys 'date', 'miles', 'price', and 'weight'
    - Rules (dict) : Dict of rules to apply to the data (Not used here for now)
    
    Returns:
    A tuple of two dicts, the first is valid data, and the second is invalid data
    
    Logic functions as follows:
    - 'date' must be an int and a unix time stamp
    - 'miles', 'price', and 'weight' must be greater than min or lower than max
    - NaN values must be considered invalid
    
    Given that all of the logic is met for the values, it is added to the valid data dict.
    If the logic is not me then the values is placed in the invalid data dict.
    """
    
    # dicts for valid and invalid_data
    
    valid_data = {}
    invalid_data = {}

    
    # Max Values
    max_miles = max(data['miles'])
    max_price = max(data['price'])
    max_weight = max(data['weight'])
    
    # Min Values
    min_miles = min(data['miles'])
    min_price = min(data['price'])
    min_weight = min(data['weight'])
    

    for i, _ in enumerate(data['date']):
        valid = True
        for key in data.keys():
            
            value = data[key][i]
            
            if key == 'date':
                if not isinstance(value, int):
                    valid = False
                    break
            elif key == 'miles' or key == 'price' or key == 'weight':
                if key == 'miles' and (value <= min_miles or value > max_miles or isnan(value)):
                    valid = False
                    break
                if key == 'price' and (value <= min_price or value > max_price or isnan(value)):
                    valid = False
                    break
                if key == 'weight' and (value <= min_weight or value > max_weight or isnan(value)):
                    valid = False
                    break
                

        if valid:
            valid_data[i] = {k: data[k][i] for k in data.keys()}
        else:
            invalid_data[i] = {k: data[k][i] for k in data.keys()}
    
    return valid_data, invalid_data


pipeline(
    mock_api_request("www.shipper.com/api?min_date=20210101&max_date=20221231"),
    parse_json,
    validator,
)
# Out:
# ({0: {'date': 1650412800, 'miles': 571.8, 'price': 1045.0, 'weight': 37601.0},
#   5: {'date': 1628640000, 'miles': 63.0, 'price': 671.0, 'weight': 40000.0},
#   7: {'date': 1647561600,
#    'miles': 1220.0,
#    'price': 3776.03,
#    'weight': 40032.0},
#   9: {'date': 1644710400, 'miles': 336.0, 'price': 1996.92, 'weight': 24872.0},
#   12: {'date': 1631491200,
#    'miles': 1658.0,
#    'price': 7123.49,
#    'weight': 25368.0},
#   13: {'date': 1634688000,
#    'miles': 647.0,
#    'price': 1038.92,
#    'weight': 40000.0},
#   14: {'date': 1670889600,
#    'miles': 260.0,
#    'price': 1031.69,
#    'weight': 42676.0},
#   16: {'date': 1631577600,
#    'miles': 1842.0,
#    'price': 5892.06,
#    'weight': 18000.0},
#   18: {'date': 1647043200,
#    'miles': 177.0,
#    'price': 1217.63,
#    'weight': 13063.0},
#   19: {'date': 1635724800,
#    'miles': 1128.0,
#    'price': 6308.4,
#    'weight': 40000.0},
#   22: {'date': 1660348800,
#    'miles': 475.0,
#    'price': 1734.73,
#    'weight': 34564.0},
#   26: {'date': 1635984000, 'miles': 241.0, 'price': 584.63, 'weight': 41540.0},
#   27: {'date': 1646006400,
#    'miles': 672.0,
#    'price': 1957.76,
#    'weight': 40000.0},
#   28: {'date': 1626912000, 'miles': 66.0, 'price': 246.44, 'weight': 40000.0},
#   29: {'date': 1638316800, 'miles': 44.0, 'price': 425.96, 'weight': 8834.0},
#   30: {'date': 1617062400, 'miles': 620.0, 'price': 3333.0, 'weight': 35000.0},
#   32: {'date': 1627776000, 'miles': 109.0, 'price': 300.0, 'weight': 40000.0},
#   33: {'date': 1629244800,
#    'miles': 931.0,
#    'price': 3384.78,
#    'weight': 29224.0},
#   34: {'date': 1635379200,
#    'miles': 2346.0,
#    'price': 4903.14,
#    'weight': 2862.0},
#   35: {'date': 1623974400,
#    'miles': 730.0,
#    'price': 1433.68,
#    'weight': 36344.0},
#   37: {'date': 1647475200,
#    'miles': 1152.29,
#    'price': 2878.32,
#    'weight': 40000.0},
#   38: {'date': 1618358400, 'miles': 750.0, 'price': 1912.5, 'weight': 35000.0},
#   39: {'date': 1663027200,
#    'miles': 1258.0,
#    'price': 4123.45,
#    'weight': 25027.0},
#   40: {'date': 1642636800,
#    'miles': 270.0,
#    'price': 2371.96,
#    'weight': 44060.0},
#   41: {'date': 1637107200,
#    'miles': 2610.0,
#    'price': 5159.87,
#    'weight': 36674.0},
#   42: {'date': 1637107200,
#    'miles': 403.0,
#    'price': 2177.33,
#    'weight': 16220.0},
#   44: {'date': 1630281600, 'miles': 282.0, 'price': 136.15, 'weight': 40000.0},
#   46: {'date': 1635120000, 'miles': 382.2, 'price': 760.0, 'weight': 13500.0},
#   47: {'date': 1635465600, 'miles': 74.0, 'price': 164.11, 'weight': 40000.0},
#   48: {'date': 1628726400,
#    'miles': 122.0,
#    'price': 1235.01,
#    'weight': 40000.0},
#   49: {'date': 1635465600,
#    'miles': 1046.07,
#    'price': 1595.75,
#    'weight': 40000.0},
#   50: {'date': 1627344000,
#    'miles': 830.0,
#    'price': 3918.74,
#    'weight': 16242.0},
#   51: {'date': 1618358400, 'miles': 28.0, 'price': 496.35, 'weight': 40000.0},
#   52: {'date': 1640563200,
#    'miles': 1259.0,
#    'price': 7057.94,
#    'weight': 4065.0},
#   53: {'date': 1624147200,
#    'miles': 1033.0,
#    'price': 4519.7,
#    'weight': 41902.0},
#   54: {'date': 1640649600,
#    'miles': 842.0,
#    'price': 3901.44,
#    'weight': 24708.0},
#   55: {'date': 1646611200,
#    'miles': 495.0,
#    'price': 1858.22,
#    'weight': 40453.0},
#   56: {'date': 1638489600,
#    'miles': 1765.6,
#    'price': 2535.0,
#    'weight': 23697.0},
#   57: {'date': 1627862400, 'miles': 30.0, 'price': 314.07, 'weight': 12010.0},
#   59: {'date': 1665360000, 'miles': 188.9, 'price': 700.0, 'weight': 44500.0},
#   60: {'date': 1638662400,
#    'miles': 624.42,
#    'price': 1612.16,
#    'weight': 40000.0},
#   61: {'date': 1636934400,
#    'miles': 2026.4,
#    'price': 2400.0,
#    'weight': 39556.0},
#   62: {'date': 1640044800,
#    'miles': 844.91,
#    'price': 1168.14,
#    'weight': 40000.0},
#   63: {'date': 1663891200,
#    'miles': 739.0,
#    'price': 1885.91,
#    'weight': 41672.0},
#   66: {'date': 1662595200,
#    'miles': 1667.0,
#    'price': 4473.12,
#    'weight': 19629.0},
#   67: {'date': 1668470400,
#    'miles': 419.0,
#    'price': 1300.19,
#    'weight': 40201.0},
#   69: {'date': 1644969600, 'miles': 277.06, 'price': 930.0, 'weight': 28000.0},
#   72: {'date': 1632960000,
#    'miles': 901.0,
#    'price': 5261.06,
#    'weight': 40000.0},
#   73: {'date': 1629763200,
#    'miles': 542.0,
#    'price': 2116.16,
#    'weight': 39219.0},
#   74: {'date': 1634774400, 'miles': 187.0, 'price': 686.68, 'weight': 26937.0},
#   75: {'date': 1644192000,
#    'miles': 839.0,
#    'price': 2655.53,
#    'weight': 37761.0},
#   76: {'date': 1649635200, 'miles': 241.0, 'price': 620.1, 'weight': 37551.0},
#   77: {'date': 1651017600, 'miles': 253.0, 'price': 1144.2, 'weight': 2550.0},
#   78: {'date': 1668038400, 'miles': 39.0, 'price': 26.92, 'weight': 38007.0},
#   80: {'date': 1665964800, 'miles': 370.0, 'price': 996.76, 'weight': 35968.0},
#   81: {'date': 1630281600, 'miles': 10.0, 'price': 57.72, 'weight': 40000.0},
#   82: {'date': 1632441600, 'miles': 202.0, 'price': 765.92, 'weight': 40000.0},
#   83: {'date': 1628812800, 'miles': 873.0, 'price': 5312.5, 'weight': 40000.0},
#   85: {'date': 1634256000, 'miles': 72.0, 'price': 34.46, 'weight': 40000.0},
#   86: {'date': 1629763200, 'miles': 202.0, 'price': 219.53, 'weight': 40000.0},
#   87: {'date': 1647820800,
#    'miles': 2214.7,
#    'price': 3302.0,
#    'weight': 36000.0},
#   89: {'date': 1635724800, 'miles': 28.0, 'price': 199.4, 'weight': 40000.0},
#   90: {'date': 1667865600, 'miles': 196.0, 'price': 528.08, 'weight': 39338.0},
#   91: {'date': 1621296000, 'miles': 24.0, 'price': 115.19, 'weight': 40000.0},
#   94: {'date': 1629763200, 'miles': 97.0, 'price': 740.74, 'weight': 40935.0},
#   95: {'date': 1637712000,
#    'miles': 995.12,
#    'price': 5040.0,
#    'weight': 26400.0},
#   96: {'date': 1639699200,
#    'miles': 1697.0,
#    'price': 6034.86,
#    'weight': 41800.0},
#   97: {'date': 1628467200,
#    'miles': 449.0,
#    'price': 1836.71,
#    'weight': 40000.0},
#   98: {'date': 1649808000, 'miles': 932.5, 'price': 2015.0, 'weight': 40533.0},
#   99: {'date': 1631923200,
#    'miles': 1786.37,
#    'price': 2347.65,
#    'weight': 40000.0},
#   100: {'date': 1638144000, 'miles': 740.3, 'price': 648.6, 'weight': 40000.0},
#   103: {'date': 1652486400,
#    'miles': 1420.0,
#    'price': 4693.54,
#    'weight': 40000.0},
#   104: {'date': 1663632000,
#    'miles': 1238.0,
#    'price': 3110.94,
#    'weight': 37336.0},
#   105: {'date': 1629158400,
#    'miles': 555.0,
#    'price': 964.13,
#    'weight': 21770.0},
#   106: {'date': 1645747200,
#    'miles': 116.0,
#    'price': 490.38,
#    'weight': 42500.0},
#   109: {'date': 1633910400,
#    'miles': 767.0,
#    'price': 3685.76,
#    'weight': 23850.0},
#   110: {'date': 1628553600,
#    'miles': 2327.0,
#    'price': 4158.2,
#    'weight': 42138.0},
#   111: {'date': 1632873600, 'miles': 84.0, 'price': 387.78, 'weight': 42000.0},
#   112: {'date': 1637366400,
#    'miles': 1030.53,
#    'price': 2250.0,
#    'weight': 40000.0},
#   114: {'date': 1641254400,
#    'miles': 518.0,
#    'price': 1662.22,
#    'weight': 11637.0},
#   115: {'date': 1620864000,
#    'miles': 818.0,
#    'price': 2932.17,
#    'weight': 40000.0},
#   116: {'date': 1647216000,
#    'miles': 469.9,
#    'price': 1313.0,
#    'weight': 38000.0},
#   117: {'date': 1642291200,
#    'miles': 386.24,
#    'price': 1496.0,
#    'weight': 40000.0},
#   118: {'date': 1634428800, 'miles': 92.0, 'price': 746.59, 'weight': 38168.0},
#   119: {'date': 1646697600,
#    'miles': 744.0,
#    'price': 1607.04,
#    'weight': 30000.0},
#   120: {'date': 1625875200, 'miles': 8.0, 'price': 178.37, 'weight': 38884.0},
#   121: {'date': 1634256000,
#    'miles': 555.0,
#    'price': 1432.81,
#    'weight': 21607.0},
#   122: {'date': 1630454400, 'miles': 53.0, 'price': 978.16, 'weight': 40000.0},
#   123: {'date': 1649808000,
#    'miles': 640.8,
#    'price': 1179.0,
#    'weight': 19282.0},
#   124: {'date': 1619136000, 'miles': 132.0, 'price': 16.05, 'weight': 345.0},
#   125: {'date': 1632441600,
#    'miles': 1382.0,
#    'price': 3384.59,
#    'weight': 25422.0},
#   126: {'date': 1612742400,
#    'miles': 1069.0,
#    'price': 2343.59,
#    'weight': 41778.0},
#   127: {'date': 1650931200,
#    'miles': 483.0,
#    'price': 1732.16,
#    'weight': 35263.0},
#   128: {'date': 1635033600, 'miles': 33.0, 'price': 153.29, 'weight': 40000.0},
#   130: {'date': 1630281600,
#    'miles': 199.0,
#    'price': 727.06,
#    'weight': 20595.0},
#   133: {'date': 1633564800,
#    'miles': 657.0,
#    'price': 4011.65,
#    'weight': 5928.0},
#   134: {'date': 1631232000,
#    'miles': 737.0,
#    'price': 2160.28,
#    'weight': 40000.0},
#   135: {'date': 1623369600,
#    'miles': 1035.0,
#    'price': 2395.7,
#    'weight': 9800.0},
#   136: {'date': 1650931200,
#    'miles': 751.0,
#    'price': 3939.04,
#    'weight': 22225.0},
#   139: {'date': 1635724800,
#    'miles': 1297.13,
#    'price': 2593.52,
#    'weight': 40000.0},
#   140: {'date': 1627430400, 'miles': 30.0, 'price': 346.88, 'weight': 40000.0},
#   143: {'date': 1649462400,
#    'miles': 512.9,
#    'price': 1078.69,
#    'weight': 19873.0},
#   144: {'date': 1638748800,
#    'miles': 572.0,
#    'price': 2093.98,
#    'weight': 31869.0},
#   145: {'date': 1637712000,
#    'miles': 241.0,
#    'price': 583.24,
#    'weight': 39322.0},
#   147: {'date': 1651795200,
#    'miles': 2401.14,
#    'price': 5711.25,
#    'weight': 40000.0},
#   148: {'date': 1657756800,
#    'miles': 1667.0,
#    'price': 4508.53,
#    'weight': 19332.0},
#   149: {'date': 1644624000, 'miles': 112.7, 'price': 799.0, 'weight': 40580.0},
#   151: {'date': 1627862400, 'miles': 12.0, 'price': 165.53, 'weight': 40000.0},
#   154: {'date': 1630540800,
#    'miles': 267.05,
#    'price': 710.0,
#    'weight': 33331.0},
#   155: {'date': 1632873600,
#    'miles': 1132.09,
#    'price': 2990.0,
#    'weight': 42500.0},
#   157: {'date': 1626220800,
#    'miles': 744.0,
#    'price': 3800.0,
#    'weight': 30000.0},
#   158: {'date': 1636070400,
#    'miles': 668.0,
#    'price': 1939.03,
#    'weight': 40033.0},
#   159: {'date': 1670544000, 'miles': 52.0, 'price': 494.52, 'weight': 45444.0},
#   160: {'date': 1617062400, 'miles': 77.0, 'price': 98.21, 'weight': 40000.0},
#   161: {'date': 1646092800,
#    'miles': 207.3,
#    'price': 739.43,
#    'weight': 38000.0},
#   163: {'date': 1619481600, 'miles': 22.0, 'price': 216.88, 'weight': 40000.0},
#   164: {'date': 1640476800,
#    'miles': 1422.66,
#    'price': 1639.83,
#    'weight': 40000.0},
#   165: {'date': 1642377600,
#    'miles': 401.0,
#    'price': 2141.73,
#    'weight': 28490.0},
#   166: {'date': 1636502400,
#    'miles': 916.0,
#    'price': 2974.0,
#    'weight': 22935.0},
#   167: {'date': 1649203200, 'miles': 122.0, 'price': 464.24, 'weight': 2462.0},
#   168: {'date': 1648512000,
#    'miles': 165.4,
#    'price': 1201.25,
#    'weight': 28472.0},
#   169: {'date': 1631923200, 'miles': 62.0, 'price': 70.58, 'weight': 40000.0},
#   170: {'date': 1631145600, 'miles': 48.0, 'price': 129.9, 'weight': 40000.0},
#   171: {'date': 1631577600,
#    'miles': 800.0,
#    'price': 2100.0,
#    'weight': 40460.0},
#   175: {'date': 1651536000,
#    'miles': 996.18,
#    'price': 2024.13,
#    'weight': 40000.0},
#   176: {'date': 1632873600,
#    'miles': 424.0,
#    'price': 1161.09,
#    'weight': 40000.0},
#   177: {'date': 1629072000,
#    'miles': 1485.0,
#    'price': 3608.55,
#    'weight': 25000.0},
#   178: {'date': 1636329600,
#    'miles': 950.13,
#    'price': 2850.0,
#    'weight': 33091.0},
#   179: {'date': 1636329600,
#    'miles': 634.0,
#    'price': 2462.05,
#    'weight': 40221.0},
#   184: {'date': 1631232000,
#    'miles': 848.0,
#    'price': 4305.69,
#    'weight': 20175.0},
#   185: {'date': 1671148800,
#    'miles': 1068.0,
#    'price': 3517.63,
#    'weight': 38515.0},
#   187: {'date': 1631664000,
#    'miles': 705.0,
#    'price': 3429.58,
#    'weight': 17000.0},
#   188: {'date': 1633046400,
#    'miles': 877.3,
#    'price': 2210.0,
#    'weight': 23211.0},
#   189: {'date': 1639612800,
#    'miles': 487.63,
#    'price': 1151.4,
#    'weight': 40000.0},
#   192: {'date': 1668556800,
#    'miles': 123.0,
#    'price': 694.76,
#    'weight': 40000.0},
#   193: {'date': 1632182400,
#    'miles': 620.0,
#    'price': 2023.8,
#    'weight': 40000.0},
#   194: {'date': 1636675200,
#    'miles': 149.0,
#    'price': 879.97,
#    'weight': 40084.0},
#   197: {'date': 1628553600,
#    'miles': 710.0,
#    'price': 1839.57,
#    'weight': 17480.0},
#   201: {'date': 1631577600,
#    'miles': 1008.0,
#    'price': 4979.52,
#    'weight': 40000.0},
#   202: {'date': 1632528000,
#    'miles': 737.0,
#    'price': 2180.86,
#    'weight': 40000.0},
#   203: {'date': 1621814400, 'miles': 21.0, 'price': 322.28, 'weight': 40000.0},
#   204: {'date': 1646179200,
#    'miles': 375.0,
#    'price': 2348.0,
#    'weight': 21240.0},
#   205: {'date': 1618444800, 'miles': 213.0, 'price': 1545.5, 'weight': 3396.0},
#   206: {'date': 1636156800,
#    'miles': 999.0,
#    'price': 5202.69,
#    'weight': 40000.0},
#   207: {'date': 1620172800,
#    'miles': 475.0,
#    'price': 1684.8,
#    'weight': 40000.0},
#   208: {'date': 1623801600,
#    'miles': 649.0,
#    'price': 2754.73,
#    'weight': 40000.0},
#   209: {'date': 1660694400,
#    'miles': 278.0,
#    'price': 1293.73,
#    'weight': 44000.0},
#   210: {'date': 1640736000,
#    'miles': 603.0,
#    'price': 2425.71,
#    'weight': 33796.0},
#   211: {'date': 1633392000,
#    'miles': 744.0,
#    'price': 4100.0,
#    'weight': 30000.0},
#   213: {'date': 1916544000,
#    'miles': 146.0,
#    'price': 152.96,
#    'weight': 40000.0},
#   215: {'date': 1628035200, 'miles': 102.0, 'price': 22.1, 'weight': 40000.0},
#   216: {'date': 1656028800, 'miles': 17.0, 'price': 12.44, 'weight': 28960.0},
#   218: {'date': 1634688000, 'miles': 29.0, 'price': 220.65, 'weight': 40000.0},
#   219: {'date': 1643846400,
#    'miles': 647.0,
#    'price': 2157.95,
#    'weight': 40464.0},
#   221: {'date': 1621641600,
#    'miles': 755.0,
#    'price': 1546.04,
#    'weight': 40000.0},
#   222: {'date': 1634515200,
#    'miles': 271.98,
#    'price': 1253.98,
#    'weight': 40000.0},
#   223: {'date': 1649289600, 'miles': 688.8, 'price': 749.0, 'weight': 40000.0},
#   224: {'date': 1634688000, 'miles': 97.0, 'price': 796.56, 'weight': 29050.0},
#   225: {'date': 1629072000,
#    'miles': 976.0,
#    'price': 2283.74,
#    'weight': 41887.0},
#   226: {'date': 1627603200,
#    'miles': 163.0,
#    'price': 632.91,
#    'weight': 41274.0},
#   227: {'date': 1665014400,
#    'miles': 378.0,
#    'price': 848.45,
#    'weight': 41967.0},
#   228: {'date': 1645488000,
#    'miles': 1497.15,
#    'price': 3280.0,
#    'weight': 45000.0},
#   229: {'date': 1644364800,
#    'miles': 144.0,
#    'price': 710.71,
#    'weight': 43500.0},
#   231: {'date': 1669680000, 'miles': 93.0, 'price': 950.06, 'weight': 30635.0},
#   232: {'date': 1633305600,
#    'miles': 308.99,
#    'price': 430.41,
#    'weight': 40000.0},
#   235: {'date': 1647475200,
#    'miles': 155.45,
#    'price': 860.0,
#    'weight': 10682.0},
#   236: {'date': 1631491200,
#    'miles': 1763.0,
#    'price': 6400.62,
#    'weight': 40000.0},
#   237: {'date': 1653523200, 'miles': 79.0, 'price': 607.47, 'weight': 20720.0},
#   238: {'date': 1633910400,
#    'miles': 524.65,
#    'price': 1008.68,
#    'weight': 40000.0},
#   239: {'date': 1656288000,
#    'miles': 272.0,
#    'price': 1518.93,
#    'weight': 12587.0},
#   240: {'date': 1616371200, 'miles': 213.0, 'price': 659.9, 'weight': 40000.0},
#   241: {'date': 1630540800,
#    'miles': 696.85,
#    'price': 943.94,
#    'weight': 40000.0},
#   242: {'date': 1632355200,
#    'miles': 1704.0,
#    'price': 4788.24,
#    'weight': 43177.0},
#   244: {'date': 1633651200, 'miles': 26.0, 'price': 9.89, 'weight': 43300.0},
#   245: {'date': 1647302400,
#    'miles': 1420.0,
#    'price': 4500.92,
#    'weight': 42988.0},
#   247: {'date': 1636329600, 'miles': 49.0, 'price': 241.8, 'weight': 40000.0},
#   248: {'date': 1645315200,
#    'miles': 852.95,
#    'price': 1575.4,
#    'weight': 40000.0},
#   253: {'date': 1616025600, 'miles': 360.0, 'price': 918.0, 'weight': 15000.0},
#   257: {'date': 1632009600,
#    'miles': 118.0,
#    'price': 222.19,
#    'weight': 40000.0},
#   258: {'date': 1634860800, 'miles': 24.0, 'price': 33.6, 'weight': 4525.0},
#   259: {'date': 1622592000, 'miles': 36.0, 'price': 171.33, 'weight': 40000.0},
#   261: {'date': 1645660800,
#    'miles': 3172.02,
#    'price': 4249.76,
#    'weight': 40000.0},
#   262: {'date': 1621814400,
#    'miles': 1525.0,
#    'price': 3820.0,
#    'weight': 38235.0},
#   263: {'date': 1635206400,
#    'miles': 582.58,
#    'price': 1869.74,
#    'weight': 40000.0},
#   265: {'date': 1630713600,
#    'miles': 436.13,
#    'price': 1261.51,
#    'weight': 40000.0},
#   266: {'date': 1617753600, 'miles': 212.0, 'price': 710.2, 'weight': 9817.0},
#   268: {'date': 1632700800,
#    'miles': 427.0,
#    'price': 1582.28,
#    'weight': 27554.0},
#   269: {'date': 1629676800,
#    'miles': 328.0,
#    'price': 1190.64,
#    'weight': 12000.0},
#   270: {'date': 1629590400,
#    'miles': 388.0,
#    'price': 1466.66,
#    'weight': 40000.0},
#   271: {'date': 1646092800,
#    'miles': 442.59,
#    'price': 1600.0,
#    'weight': 25979.0},
#   272: {'date': 1630627200,
#    'miles': 215.0,
#    'price': 882.63,
#    'weight': 40992.0},
#   275: {'date': 1633046400,
#    'miles': 620.0,
#    'price': 2030.0,
#    'weight': 40000.0},
#   276: {'date': 1635120000,
#    'miles': 2022.0,
#    'price': 5499.84,
#    'weight': 26700.0},
#   278: {'date': 1637020800,
#    'miles': 308.0,
#    'price': 1159.42,
#    'weight': 37735.0},
#   279: {'date': 1640044800,
#    'miles': 264.06,
#    'price': 1430.0,
#    'weight': 36000.0},
#   281: {'date': 1627516800,
#    'miles': 753.0,
#    'price': 2293.79,
#    'weight': 3000.0},
#   282: {'date': 1646006400,
#    'miles': 233.48,
#    'price': 900.0,
#    'weight': 35000.0},
#   283: {'date': 1635206400,
#    'miles': 2820.0,
#    'price': 10731.56,
#    'weight': 40000.0},
#   286: {'date': 1634947200,
#    'miles': 450.0,
#    'price': 1934.68,
#    'weight': 38729.0},
#   287: {'date': 1633046400,
#    'miles': 132.0,
#    'price': 1631.76,
#    'weight': 5000.0},
#   289: {'date': 1628208000,
#    'miles': 984.0,
#    'price': 2149.91,
#    'weight': 40880.0},
#   291: {'date': 1631404800, 'miles': 43.0, 'price': 112.51, 'weight': 40000.0},
#   292: {'date': 1631577600,
#    'miles': 800.0,
#    'price': 2600.0,
#    'weight': 40467.0},
#   293: {'date': 1641859200,
#    'miles': 881.0,
#    'price': 1674.43,
#    'weight': 27922.0},
#   294: {'date': 1669766400,
#    'miles': 596.0,
#    'price': 2307.21,
#    'weight': 42500.0},
#   295: {'date': 1627862400, 'miles': 67.0, 'price': 7.57, 'weight': 40000.0},
#   296: {'date': 1649376000,
#    'miles': 680.75,
#    'price': 2051.55,
#    'weight': 40000.0},
#   299: {'date': 1652400000,
#    'miles': 582.58,
#    'price': 1697.26,
#    'weight': 40000.0},
#   300: {'date': 1636070400,
#    'miles': 1401.0,
#    'price': 4891.23,
#    'weight': 40000.0},
#   301: {'date': 1621036800,
#    'miles': 539.0,
#    'price': 2212.11,
#    'weight': 40000.0},
#   303: {'date': 1633737600, 'miles': 49.0, 'price': 461.98, 'weight': 42275.0},
#   305: {'date': 1641340800, 'miles': 26.0, 'price': 10.67, 'weight': 42905.0},
#   306: {'date': 1647388800,
#    'miles': 317.04,
#    'price': 895.54,
#    'weight': 40000.0},
#   307: {'date': 1628553600, 'miles': 307.0, 'price': 850.38, 'weight': 8992.0},
#   308: {'date': 1644278400,
#    'miles': 623.64,
#    'price': 2660.0,
#    'weight': 30773.0},
#   310: {'date': 1629417600,
#    'miles': 1646.0,
#    'price': 6231.65,
#    'weight': 40000.0},
#   311: {'date': 1648252800,
#    'miles': 556.27,
#    'price': 1500.0,
#    'weight': 14277.0},
#   312: {'date': 1620777600, 'miles': 25.0, 'price': 232.09, 'weight': 40000.0},
#   313: {'date': 1632268800, 'miles': 98.0, 'price': 838.12, 'weight': 40000.0},
#   314: {'date': 1646438400,
#    'miles': 1083.09,
#    'price': 1625.3,
#    'weight': 40000.0},
#   315: {'date': 1650240000, 'miles': 766.0, 'price': 490.52, 'weight': 8903.0},
#   316: {'date': 1625011200,
#    'miles': 744.0,
#    'price': 2811.27,
#    'weight': 18393.0},
#   317: {'date': 1629763200, 'miles': 67.0, 'price': 249.49, 'weight': 40000.0},
#   318: {'date': 1645574400,
#    'miles': 555.0,
#    'price': 2523.06,
#    'weight': 20370.0},
#   319: {'date': 1618790400, 'miles': 18.0, 'price': 206.51, 'weight': 40000.0},
#   321: {'date': 1638921600,
#    'miles': 882.9,
#    'price': 1816.41,
#    'weight': 25768.0},
#   323: {'date': 1672099200,
#    'miles': 442.0,
#    'price': 1751.7,
#    'weight': 30326.0},
#   324: {'date': 1617840000,
#    'miles': 1348.0,
#    'price': 5455.8,
#    'weight': 40000.0},
#   326: {'date': 1646179200,
#    'miles': 340.0,
#    'price': 1882.46,
#    'weight': 21718.0},
#   328: {'date': 1613692800,
#    'miles': 883.0,
#    'price': 2728.47,
#    'weight': 21922.0},
#   331: {'date': 1652572800,
#    'miles': 257.5,
#    'price': 1069.08,
#    'weight': 40000.0},
#   332: {'date': 1628380800,
#    'miles': 911.0,
#    'price': 3286.07,
#    'weight': 38601.0},
#   333: {'date': 1630886400,
#    'miles': 987.0,
#    'price': 2602.41,
#    'weight': 40000.0},
#   334: {'date': 1668643200,
#    'miles': 520.8,
#    'price': 1167.52,
#    'weight': 43663.0},
#   335: {'date': 1664150400,
#    'miles': 218.0,
#    'price': 1055.66,
#    'weight': 43500.0},
#   336: {'date': 1627948800, 'miles': 215.0, 'price': 878.1, 'weight': 39844.0},
#   337: {'date': 1622160000,
#    'miles': 693.0,
#    'price': 2245.92,
#    'weight': 40725.0},
#   338: {'date': 1649289600,
#    'miles': 1945.0,
#    'price': 11227.85,
#    'weight': 41580.0},
#   339: {'date': 1635897600,
#    'miles': 2423.67,
#    'price': 3261.87,
#    'weight': 40000.0},
#   343: {'date': 1633910400, 'miles': 154.5, 'price': 100.0, 'weight': 40000.0},
#   344: {'date': 1624924800,
#    'miles': 218.0,
#    'price': 1017.41,
#    'weight': 40000.0},
#   345: {'date': 1616371200, 'miles': 102.0, 'price': 5.82, 'weight': 40000.0},
#   346: {'date': 1651622400, 'miles': 72.0, 'price': 532.91, 'weight': 42500.0},
#   347: {'date': 1638921600,
#    'miles': 984.0,
#    'price': 1985.91,
#    'weight': 40372.0},
#   350: {'date': 1640217600,
#    'miles': 1529.0,
#    'price': 7658.68,
#    'weight': 19587.0},
#   354: {'date': 1635292800,
#    'miles': 157.0,
#    'price': 1773.49,
#    'weight': 40000.0},
#   355: {'date': 1650585600, 'miles': 207.6, 'price': 642.7, 'weight': 40000.0},
#   356: {'date': 1662940800, 'miles': 30.0, 'price': 356.41, 'weight': 23876.0},
#   357: {'date': 1636329600,
#    'miles': 3204.2,
#    'price': 3988.15,
#    'weight': 40000.0},
#   358: {'date': 1636416000,
#    'miles': 657.92,
#    'price': 2000.0,
#    'weight': 44200.0},
#   359: {'date': 1666828800,
#    'miles': 2307.0,
#    'price': 4901.71,
#    'weight': 11902.0},
#   362: {'date': 1653091200,
#    'miles': 932.5,
#    'price': 2015.0,
#    'weight': 32477.0},
#   363: {'date': 1644364800,
#    'miles': 469.9,
#    'price': 1313.0,
#    'weight': 38000.0},
#   364: {'date': 1634688000,
#    'miles': 406.0,
#    'price': 1775.84,
#    'weight': 28164.0},
#   368: {'date': 1623628800, 'miles': 29.0, 'price': 149.34, 'weight': 40000.0},
#   371: {'date': 1639612800,
#    'miles': 1112.06,
#    'price': 1316.85,
#    'weight': 40000.0},
#   375: {'date': 1646092800, 'miles': 39.0, 'price': 19.12, 'weight': 40272.0},
#   377: {'date': 1632873600,
#    'miles': 954.49,
#    'price': 1600.0,
#    'weight': 40000.0},
#   378: {'date': 1621296000, 'miles': 18.0, 'price': 240.87, 'weight': 40000.0},
#   380: {'date': 1631577600,
#    'miles': 3136.61,
#    'price': 3000.65,
#    'weight': 40000.0},
#   381: {'date': 1664236800,
#    'miles': 756.0,
#    'price': 1887.62,
#    'weight': 32747.0},
#   382: {'date': 1634428800,
#    'miles': 1147.46,
#    'price': 1901.63,
#    'weight': 40000.0},
#   384: {'date': 1640563200,
#    'miles': 1440.0,
#    'price': 4359.46,
#    'weight': 39653.0},
#   386: {'date': 1614384000,
#    'miles': 362.0,
#    'price': 1283.18,
#    'weight': 40000.0},
#   387: {'date': 1643846400, 'miles': 122.1, 'price': 435.0, 'weight': 16.0},
#   389: {'date': 1640649600,
#    'miles': 1854.0,
#    'price': 8222.68,
#    'weight': 26255.0},
#   390: {'date': 1645401600,
#    'miles': 1075.04,
#    'price': 3366.72,
#    'weight': 40000.0},
#   391: {'date': 1620345600,
#    'miles': 476.0,
#    'price': 994.84,
#    'weight': 10102.0},
#   392: {'date': 1664150400,
#    'miles': 433.0,
#    'price': 1668.94,
#    'weight': 34549.0},
#   393: {'date': 1636588800,
#    'miles': 597.0,
#    'price': 2535.67,
#    'weight': 33601.0},
#   394: {'date': 1665964800,
#    'miles': 649.0,
#    'price': 1679.57,
#    'weight': 40069.0},
#   395: {'date': 1628467200,
#    'miles': 241.0,
#    'price': 575.31,
#    'weight': 40354.0},
#   398: {'date': 1665964800,
#    'miles': 1910.0,
#    'price': 6489.39,
#    'weight': 20034.0},
#   400: {'date': 1652745600,
#    'miles': 769.27,
#    'price': 2566.86,
#    'weight': 40000.0},
#   402: {'date': 1644796800,
#    'miles': 504.0,
#    'price': 1038.18,
#    'weight': 42000.0},
#   403: {'date': 1655942400, 'miles': 24.0, 'price': 22.33, 'weight': 27707.0},
#   404: {'date': 1634256000,
#    'miles': 370.0,
#    'price': 1033.13,
#    'weight': 36097.0},
#   405: {'date': 1614816000,
#    'miles': 542.0,
#    'price': 1794.02,
#    'weight': 22305.0},
#   407: {'date': 1635465600,
#    'miles': 2640.0,
#    'price': 9292.51,
#    'weight': 38598.0},
#   408: {'date': 1632700800,
#    'miles': 1694.0,
#    'price': 6514.43,
#    'weight': 40000.0},
#   409: {'date': 1628812800,
#    'miles': 1948.0,
#    'price': 7625.58,
#    'weight': 40000.0},
#   410: {'date': 1648598400,
#    'miles': 337.9,
#    'price': 1162.202457631453,
#    'weight': 40000.0},
#   412: {'date': 1644796800,
#    'miles': 257.0,
#    'price': 1385.33,
#    'weight': 36060.0},
#   413: {'date': 1646697600,
#    'miles': 682.0,
#    'price': 2397.13,
#    'weight': 28563.0},
#   415: {'date': 1646092800,
#    'miles': 2092.15,
#    'price': 3493.52,
#    'weight': 40000.0},
#   416: {'date': 1635897600,
#    'miles': 199.0,
#    'price': 969.45,
#    'weight': 20828.0},
#   418: {'date': 1615420800, 'miles': 19.0, 'price': 148.6, 'weight': 40000.0},
#   419: {'date': 1629417600,
#    'miles': 525.0,
#    'price': 1545.34,
#    'weight': 36636.0},
#   420: {'date': 1633564800,
#    'miles': 1035.0,
#    'price': 2679.4,
#    'weight': 30386.0},
#   421: {'date': 1644278400,
#    'miles': 563.27,
#    'price': 2499.7,
#    'weight': 40000.0},
#   422: {'date': 1623715200,
#    'miles': 336.43,
#    'price': 1330.0,
#    'weight': 35542.0},
#   423: {'date': 1628726400,
#    'miles': 146.0,
#    'price': 180.29,
#    'weight': 40000.0},
#   426: {'date': 1630540800,
#    'miles': 577.0,
#    'price': 3133.11,
#    'weight': 40000.0},
#   427: {'date': 1632787200,
#    'miles': 693.0,
#    'price': 2062.29,
#    'weight': 32078.0},
#   428: {'date': 1669161600,
#    'miles': 269.5,
#    'price': 1121.3,
#    'weight': 45254.0},
#   429: {'date': 1643328000,
#    'miles': 449.0,
#    'price': 4053.2,
#    'weight': 15000.0},
#   430: {'date': 1636934400,
#    'miles': 27.36,
#    'price': 414.28,
#    'weight': 40000.0},
#   431: {'date': 1631145600,
#    'miles': 800.0,
#    'price': 2700.0,
#    'weight': 40738.0},
#   432: {'date': 1652313600,
#    'miles': 849.7,
#    'price': 2950.5,
#    'weight': 21580.0},
#   433: {'date': 1622505600,
#    'miles': 909.0,
#    'price': 1872.54,
#    'weight': 40000.0},
#   435: {'date': 1638835200,
#    'miles': 286.0,
#    'price': 724.73,
#    'weight': 41436.0},
#   436: {'date': 1622764800,
#    'miles': 1267.0,
#    'price': 5844.98,
#    'weight': 40000.0},
#   438: {'date': 1634169600,
#    'miles': 698.46,
#    'price': 1341.06,
#    'weight': 40000.0},
#   439: {'date': 1665100800,
#    'miles': 777.0,
#    'price': 3144.64,
#    'weight': 23138.0},
#   440: {'date': 1631836800,
#    'miles': 149.0,
#    'price': 873.93,
#    'weight': 38696.0},
#   441: {'date': 1633910400,
#    'miles': 848.12,
#    'price': 1731.2,
#    'weight': 40000.0},
#   442: {'date': 1625616000,
#    'miles': 368.0,
#    'price': 1575.58,
#    'weight': 18736.0},
#   443: {'date': 1626825600,
#    'miles': 197.0,
#    'price': 142.01,
#    'weight': 40000.0},
#   444: {'date': 1630368000,
#    'miles': 1412.0,
#    'price': 3585.84,
#    'weight': 38889.0},
#   446: {'date': 1650326400,
#    'miles': 550.3,
#    'price': 1440.0,
#    'weight': 33167.0},
#   447: {'date': 1634342400,
#    'miles': 102.0,
#    'price': 281.86,
#    'weight': 40000.0},
#   448: {'date': 1642550400,
#    'miles': 558.6,
#    'price': 1645.2,
#    'weight': 35127.0},
#   449: {'date': 1646006400,
#    'miles': 436.13,
#    'price': 968.83,
#    'weight': 40000.0},
#   450: {'date': 1643846400,
#    'miles': 682.0,
#    'price': 3162.87,
#    'weight': 32921.0},
#   452: {'date': 1634256000, 'miles': 107.0, 'price': 573.52, 'weight': 9810.0},
#   453: {'date': 1617926400,
#    'miles': 1520.0,
#    'price': 4180.0,
#    'weight': 40640.0},
#   454: {'date': 1648771200,
#    'miles': 241.0,
#    'price': 625.93,
#    'weight': 40740.0},
#   455: {'date': 1631059200,
#    'miles': 725.0,
#    'price': 3635.28,
#    'weight': 28537.0},
#   456: {'date': 1647475200,
#    'miles': 347.0,
#    'price': 10000.0,
#    'weight': 16961.0},
#   457: {'date': 1633564800,
#    'miles': 1686.0,
#    'price': 6853.53,
#    'weight': 40000.0},
#   458: {'date': 1629849600,
#    'miles': 344.0,
#    'price': 1910.13,
#    'weight': 40000.0},
#   459: {'date': 1634428800, 'miles': 22.0, 'price': 94.68, 'weight': 40000.0},
#   463: {'date': 1625270400,
#    'miles': 2897.0,
#    'price': 11390.96,
#    'weight': 40000.0},
#   464: {'date': 1659484800,
#    'miles': 983.0,
#    'price': 2453.71,
#    'weight': 39057.0},
#   465: {'date': 1642809600,
#    'miles': 781.0,
#    'price': 3759.26,
#    'weight': 9320.0},
#   467: {'date': 1633046400,
#    'miles': 995.4,
#    'price': 4668.0,
#    'weight': 37609.0},
#   468: {'date': 1647129600,
#    'miles': 751.7,
#    'price': 2445.0,
#    'weight': 20000.0},
#   470: {'date': 1654214400, 'miles': 26.0, 'price': 18.99, 'weight': 43930.0},
#   471: {'date': 1621209600,
#    'miles': 960.0,
#    'price': 2624.4,
#    'weight': 38500.0},
#   472: {'date': 1632268800,
#    'miles': 424.0,
#    'price': 803.59,
#    'weight': 40000.0},
#   473: {'date': 1621382400, 'miles': 10.0, 'price': 329.0, 'weight': 8220.0},
#   474: {'date': 1644278400,
#    'miles': 867.5,
#    'price': 1860.0,
#    'weight': 40000.0},
#   476: {'date': 1615507200,
#    'miles': 2959.0,
#    'price': 9928.96,
#    'weight': 40000.0},
#   477: {'date': 1642118400,
#    'miles': 3619.41,
#    'price': 4718.85,
#    'weight': 40000.0},
#   479: {'date': 1635811200,
#    'miles': 1525.66,
#    'price': 2924.58,
#    'weight': 40000.0},
#   480: {'date': 1646784000, 'miles': 92.0, 'price': 801.25, 'weight': 41650.0},
#   482: {'date': 1658188800,
#    'miles': 158.0,
#    'price': 1455.41,
#    'weight': 41923.0},
#   484: {'date': 1620864000,
#    'miles': 1420.0,
#    'price': 2901.3700000000003,
#    'weight': 38400.0},
#   485: {'date': 1632528000,
#    'miles': 891.0,
#    'price': 4150.81,
#    'weight': 41748.0},
#   486: {'date': 1630022400,
#    'miles': 290.0,
#    'price': 3600.0,
#    'weight': 48080.0},
#   487: {'date': 1653436800,
#    'miles': 2206.0,
#    'price': 6270.66,
#    'weight': 30660.0},
#   488: {'date': 1624060800, 'miles': 91.0, 'price': 55.67, 'weight': 40000.0},
#   490: {'date': 1633910400, 'miles': 24.0, 'price': 32.88, 'weight': 5243.0},
#   491: {'date': 1646784000,
#    'miles': 853.0,
#    'price': 5372.3,
#    'weight': 11991.0},
#   492: {'date': 1630454400,
#    'miles': 160.0,
#    'price': 193.33,
#    'weight': 40000.0},
#   493: {'date': 1616025600, 'miles': 29.0, 'price': 124.4, 'weight': 40000.0},
#   494: {'date': 1636070400, 'miles': 289.0, 'price': 768.5, 'weight': 38667.0},
#   496: {'date': 1636675200,
#    'miles': 122.0,
#    'price': 987.58,
#    'weight': 40000.0},
#   497: {'date': 1670198400, 'miles': 18.0, 'price': 14.41, 'weight': 36254.0},
#   498: {'date': 1640649600,
#    'miles': 1305.18,
#    'price': 1749.35,
#    'weight': 40000.0},
#   499: {'date': 1645488000, 'miles': 72.0, 'price': 441.53, 'weight': 4492.0},
#   501: {'date': 1630281600,
#    'miles': 378.0,
#    'price': 1374.04,
#    'weight': 40000.0},
#   502: {'date': 1649721600,
#    'miles': 3260.53,
#    'price': 7192.3,
#    'weight': 40000.0},
#   503: {'date': 1630627200,
#    'miles': 1219.0,
#    'price': 2388.17,
#    'weight': 40000.0},
#   504: {'date': 1631577600, 'miles': 28.0, 'price': 199.4, 'weight': 40000.0},
#   505: {'date': 1634774400,
#    'miles': 373.37,
#    'price': 1509.64,
#    'weight': 40000.0},
#   506: {'date': 1645488000,
#    'miles': 521.0,
#    'price': 1271.32,
#    'weight': 41979.0},
#   507: {'date': 1625788800,
#    'miles': 1138.0,
#    'price': 6170.84,
#    'weight': 40000.0},
#   510: {'date': 1641945600,
#    'miles': 403.0,
#    'price': 3048.64,
#    'weight': 22886.0},
#   511: {'date': 1635465600,
#    'miles': 704.0,
#    'price': 3146.88,
#    'weight': 3160.0},
#   512: {'date': 1632873600,
#    'miles': 517.0,
#    'price': 1864.35,
#    'weight': 39099.0},
#   513: {'date': 1665014400,
#    'miles': 542.0,
#    'price': 1853.6,
#    'weight': 41567.0},
#   514: {'date': 1631059200,
#    'miles': 190.0,
#    'price': 1133.6,
#    'weight': 40000.0},
#   515: {'date': 1622073600,
#    'miles': 750.0,
#    'price': 2156.16,
#    'weight': 40843.0},
#   516: {'date': 1618185600, 'miles': 667.0, 'price': 1266.8, 'weight': 3000.0},
#   517: {'date': 1632355200,
#    'miles': 349.23,
#    'price': 1254.25,
#    'weight': 40000.0},
#   518: {'date': 1644796800,
#    'miles': 1342.19,
#    'price': 3511.14,
#    'weight': 40000.0},
#   519: {'date': 1628467200,
#    'miles': 1163.0,
#    'price': 2257.86,
#    'weight': 11588.0},
#   521: {'date': 1620172800,
#    'miles': 348.0,
#    'price': 1491.21,
#    'weight': 34686.0},
#   522: {'date': 1629158400, 'miles': 29.0, 'price': 269.19, 'weight': 40000.0},
#   523: {'date': 1636416000,
#    'miles': 242.0,
#    'price': 1230.54,
#    'weight': 40000.0},
#   524: {'date': 1645747200,
#    'miles': 1420.0,
#    'price': 4542.82,
#    'weight': 38400.0},
#   525: {'date': 1644796800,
#    'miles': 348.88,
#    'price': 1330.0,
#    'weight': 40000.0},
#   527: {'date': 1624838400,
#    'miles': 612.0,
#    'price': 1787.04,
#    'weight': 34484.0},
#   528: {'date': 1632268800,
#    'miles': 117.0,
#    'price': 434.36,
#    'weight': 40000.0},
#   529: {'date': 1631318400,
#    'miles': 1422.66,
#    'price': 1625.31,
#    'weight': 40000.0},
#   530: {'date': 1642118400,
#    'miles': 683.97,
#    'price': 1179.38,
#    'weight': 40000.0},
#   532: {'date': 1633996800,
#    'miles': 552.0,
#    'price': 2279.14,
#    'weight': 29937.0},
#   533: {'date': 1659916800,
#    'miles': 612.0,
#    'price': 1554.64,
#    'weight': 9164.0},
#   534: {'date': 1658707200, 'miles': 56.0, 'price': 569.04, 'weight': 41650.0},
#   535: {'date': 1633824000, 'miles': 47.0, 'price': 80.04, 'weight': 40000.0},
#   536: {'date': 1629417600, 'miles': 473.0, 'price': 127.9, 'weight': 40000.0},
#   537: {'date': 1652486400,
#    'miles': 812.72,
#    'price': 2115.95,
#    'weight': 40000.0},
#   538: {'date': 1626220800,
#    'miles': 215.0,
#    'price': 881.15,
#    'weight': 41104.0},
#   539: {'date': 1633651200,
#    'miles': 280.0,
#    'price': 106.06,
#    'weight': 40000.0},
#   540: {'date': 1637625600,
#    'miles': 813.0,
#    'price': 4087.62,
#    'weight': 32055.0},
#   541: {'date': 1631318400,
#    'miles': 449.0,
#    'price': 3212.64,
#    'weight': 40000.0},
#   543: {'date': 1631059200,
#    'miles': 307.0,
#    'price': 1460.08,
#    'weight': 40000.0},
#   547: {'date': 1631059200,
#    'miles': 629.0,
#    'price': 264.18,
#    'weight': 13911.0},
#   548: {'date': 1633132800, 'miles': 31.0, 'price': 135.57, 'weight': 40000.0},
#   550: {'date': 1652400000,
#    'miles': 339.5,
#    'price': 1300.0,
#    'weight': 25329.0},
#   553: {'date': 1660608000, 'miles': 18.0, 'price': 13.51, 'weight': 41541.0},
#   554: {'date': 1634169600, 'miles': 38.0, 'price': 995.13, 'weight': 50000.0},
#   555: {'date': 1647561600,
#    'miles': 199.4,
#    'price': 1018.9,
#    'weight': 40000.0},
#   556: {'date': 1667952000,
#    'miles': 699.0,
#    'price': 2169.8,
#    'weight': 33924.0},
#   558: {'date': 1642032000,
#    'miles': 481.6,
#    'price': 2174.52,
#    'weight': 30000.0},
#   559: {'date': 1624924800, 'miles': 68.0, 'price': 137.09, 'weight': 40000.0},
#   560: {'date': 1642118400,
#    'miles': 661.4,
#    'price': 1095.0,
#    'weight': 40500.0},
#   561: {'date': 1627257600,
#    'miles': 139.0,
#    'price': 872.85,
#    'weight': 41900.0},
#   562: {'date': 1654646400,
#    'miles': 869.0,
#    'price': 2183.05,
#    'weight': 15542.0},
#   563: {'date': 1659398400,
#    'miles': 756.0,
#    'price': 3135.54,
#    'weight': 20966.0},
#   564: {'date': 1644796800,
#    'miles': 698.7,
#    'price': 2725.0,
#    'weight': 10416.0},
#   565: {'date': 1646179200,
#    'miles': 845.3,
#    'price': 1983.49,
#    'weight': 36359.0},
#   567: {'date': 1669161600, 'miles': 228.1, 'price': 650.0, 'weight': 44910.0},
#   568: {'date': 1618617600,
#    'miles': 271.0,
#    'price': 325.68,
#    'weight': 40000.0},
#   570: {'date': 1664323200,
#    'miles': 526.0,
#    'price': 1243.52,
#    'weight': 38505.0},
#   571: {'date': 1639353600,
#    'miles': 389.0,
#    'price': 1415.43,
#    'weight': 39085.0},
#   572: {'date': 1633996800,
#    'miles': 337.0,
#    'price': 2467.38,
#    'weight': 35700.0},
#   573: {'date': 1629244800, 'miles': 19.0, 'price': 204.15, 'weight': 40000.0},
#   574: {'date': 1650931200, 'miles': 106.3, 'price': 690.0, 'weight': 24000.0},
#   575: {'date': 1631577600, 'miles': 272.0, 'price': 985.1, 'weight': 44000.0},
#   576: {'date': 1624838400,
#    'miles': 450.0,
#    'price': 914.23,
#    'weight': 39987.0},
#   577: {'date': 1652659200,
#    'miles': 296.12,
#    'price': 790.76,
#    'weight': 40000.0},
#   579: {'date': 1646265600,
#    'miles': 450.62,
#    'price': 688.8,
#    'weight': 40000.0},
#   580: {'date': 1660780800,
#    'miles': 401.0,
#    'price': 1553.65,
#    'weight': 35544.0},
#   581: {'date': 1643846400,
#    'miles': 806.0,
#    'price': 2457.69,
#    'weight': 22673.0},
#   582: {'date': 1633478400, 'miles': 8.05, 'price': 47.5, 'weight': 40000.0},
#   583: {'date': 1640736000,
#    'miles': 571.32,
#    'price': 1086.3,
#    'weight': 40000.0},
#   584: {'date': 1626134400,
#    'miles': 205.0,
#    'price': 936.96,
#    'weight': 40928.0},
#   586: {'date': 1619136000,
#    'miles': 884.0,
#    'price': 4630.34,
#    'weight': 40000.0},
#   588: {'date': 1643673600,
#    'miles': 1075.04,
#    'price': 2411.48,
#    'weight': 40000.0},
#   589: {'date': 1617840000, 'miles': 9.0, 'price': 2.19, 'weight': 40000.0},
#   591: {'date': 1632873600, 'miles': 138.0, 'price': 486.2, 'weight': 44000.0},
#   592: {'date': 1645401600, 'miles': 56.1, 'price': 330.02, 'weight': 40000.0},
#   594: {'date': 1620864000,
#    'miles': 1661.0,
#    'price': 3888.63,
#    'weight': 41624.0},
#   595: {'date': 1625097600, 'miles': 11.0, 'price': 219.96, 'weight': 40000.0},
#   597: {'date': 1647561600,
#    'miles': 651.0,
#    'price': 3376.33,
#    'weight': 41645.0},
#   598: {'date': 1635292800,
#    'miles': 448.0,
#    'price': 1952.82,
#    'weight': 40000.0},
#   599: {'date': 1661904000, 'miles': 67.0, 'price': 711.15, 'weight': 42257.0},
#   600: {'date': 1625011200, 'miles': 47.0, 'price': 234.08, 'weight': 40000.0},
#   601: {'date': 1668470400, 'miles': 96.5, 'price': 536.54, 'weight': 45254.0},
#   602: {'date': 1633737600,
#    'miles': 827.52,
#    'price': 3240.0,
#    'weight': 36209.0},
#   604: {'date': 1646092800,
#    'miles': 1420.0,
#    'price': 6052.05,
#    'weight': 42908.0},
#   607: {'date': 1667865600,
#    'miles': 286.0,
#    'price': 696.54,
#    'weight': 41197.0},
#   608: {'date': 1644537600, 'miles': 21.0, 'price': 310.21, 'weight': 23720.0},
#   609: {'date': 1662854400,
#    'miles': 1305.0,
#    'price': 4219.88,
#    'weight': 20237.0},
#   611: {'date': 1630368000, 'miles': 67.0, 'price': 249.49, 'weight': 40000.0},
#   612: {'date': 1651276800,
#    'miles': 586.0,
#    'price': 1433.08,
#    'weight': 31751.0},
#   615: {'date': 1631491200, 'miles': 52.0, 'price': 587.88, 'weight': 40000.0},
#   616: {'date': 1631059200,
#    'miles': 1771.89,
#    'price': 4134.26,
#    'weight': 40000.0},
#   617: {'date': 1643846400, 'miles': 779.3, 'price': 1314.0, 'weight': 16.0},
#   618: {'date': 1653091200,
#    'miles': 557.5,
#    'price': 1288.96,
#    'weight': 39062.0},
#   620: {'date': 1636416000,
#    'miles': 102.0,
#    'price': 595.97,
#    'weight': 41520.0},
#   621: {'date': 1632268800,
#    'miles': 492.65,
#    'price': 2380.0,
#    'weight': 40000.0},
#   622: {'date': 1623024000,
#    'miles': 332.0,
#    'price': 163.32,
#    'weight': 40000.0},
#   623: {'date': 1635984000,
#    'miles': 170.0,
#    'price': 1494.64,
#    'weight': 40000.0},
#   624: {'date': 1670889600, 'miles': 5.0, 'price': 3.61, 'weight': 39684.0},
#   625: {'date': 1663200000,
#    'miles': 249.0,
#    'price': 1152.44,
#    'weight': 9568.0},
#   627: {'date': 1639267200,
#    'miles': 1738.09,
#    'price': 3218.39,
#    'weight': 40000.0},
#   628: {'date': 1650585600,
#    'miles': 904.0,
#    'price': 2369.82,
#    'weight': 40330.0},
#   629: {'date': 1620691200,
#    'miles': 458.0,
#    'price': 1671.59,
#    'weight': 38812.0},
#   630: {'date': 1653350400,
#    'miles': 926.0,
#    'price': 3508.78,
#    'weight': 1566.0},
#   631: {'date': 1647302400,
#    'miles': 1324.49,
#    'price': 3094.48,
#    'weight': 40000.0},
#   632: {'date': 1659312000,
#    'miles': 988.0,
#    'price': 2074.34,
#    'weight': 42750.0},
#   633: {'date': 1665878400,
#    'miles': 1593.0,
#    'price': 3598.57,
#    'weight': 15807.0},
#   634: {'date': 1620345600,
#    'miles': 330.0,
#    'price': 1663.64,
#    'weight': 40000.0},
#   637: {'date': 1668643200, 'miles': 20.0, 'price': 416.38, 'weight': 25371.0},
#   638: {'date': 1635811200,
#    'miles': 1575.55,
#    'price': 3181.75,
#    'weight': 40000.0},
#   639: {'date': 1638489600,
#    'miles': 647.0,
#    'price': 1526.38,
#    'weight': 42000.0},
#   644: {'date': 1631059200, 'miles': 434.43, 'price': 900.0, 'weight': 1087.0},
#   645: {'date': 1631059200,
#    'miles': 525.0,
#    'price': 1023.07,
#    'weight': 38520.0},
#   646: {'date': 1632787200, 'miles': 78.0, 'price': 118.68, 'weight': 40000.0},
#   647: {'date': 1629244800,
#    'miles': 724.0,
#    'price': 1951.25,
#    'weight': 16942.0},
#   648: {'date': 1647820800,
#    'miles': 135.9,
#    'price': 504.86,
#    'weight': 40000.0},
#   649: {'date': 1646179200,
#    'miles': 1216.0,
#    'price': 7453.0,
#    'weight': 42099.0},
#   651: {'date': 1645833600,
#    'miles': 1189.31,
#    'price': 2789.73,
#    'weight': 40000.0},
#   652: {'date': 1642377600,
#    'miles': 1259.0,
#    'price': 3106.18,
#    'weight': 22599.0},
#   653: {'date': 1642464000, 'miles': 90.9, 'price': 1135.0, 'weight': 38138.0},
#   655: {'date': 1622073600,
#    'miles': 181.0,
#    'price': 227.04,
#    'weight': 40000.0},
#   656: {'date': 1626652800,
#    'miles': 134.0,
#    'price': 187.49,
#    'weight': 40000.0},
#   658: {'date': 1630886400,
#    'miles': 563.0,
#    'price': 1887.09,
#    'weight': 40000.0},
#   659: {'date': 1631577600,
#    'miles': 218.0,
#    'price': 497.03,
#    'weight': 40000.0},
#   660: {'date': 1643673600,
#    'miles': 164.0,
#    'price': 994.64,
#    'weight': 40392.0},
#   663: {'date': 1643932800, 'miles': 9.5, 'price': 377.96, 'weight': 8677.0},
#   664: {'date': 1631059200, 'miles': 67.0, 'price': 221.39, 'weight': 40000.0},
#   665: {'date': 1646092800,
#    'miles': 1165.5,
#    'price': 4865.0,
#    'weight': 31174.0},
#   666: {'date': 1622160000,
#    'miles': 2038.0,
#    'price': 4911.55,
#    'weight': 40000.0},
#   667: {'date': 1633046400, 'miles': 600.2, 'price': 1150.0, 'weight': 16.0},
#   668: {'date': 1643673600,
#    'miles': 387.0,
#    'price': 1821.35,
#    'weight': 40549.0},
#   670: {'date': 1629417600, 'miles': 102.0, 'price': 33.09, 'weight': 40000.0},
#   672: {'date': 1614729600,
#    'miles': 2742.0,
#    'price': 7342.08,
#    'weight': 40920.0},
#   674: {'date': 1617148800,
#    'miles': 618.27,
#    'price': 1520.0,
#    'weight': 30100.0},
#   675: {'date': 1643068800,
#    'miles': 189.9,
#    'price': 697.94,
#    'weight': 40000.0},
#   677: {'date': 1638835200,
#    'miles': 593.85,
#    'price': 867.15,
#    'weight': 40000.0},
#   678: {'date': 1668470400, 'miles': 11.0, 'price': 9.14, 'weight': 38605.0},
#   679: {'date': 1664236800,
#    'miles': 1165.0,
#    'price': 2638.66,
#    'weight': 16388.0},
#   680: {'date': 1659916800,
#    'miles': 215.0,
#    'price': 1013.08,
#    'weight': 41129.0},
#   684: {'date': 1632096000,
#    'miles': 807.89,
#    'price': 1807.2,
#    'weight': 40000.0},
#   685: {'date': 1645056000, 'miles': 18.6, 'price': 10000.0, 'weight': 16.0},
#   686: {'date': 1635811200,
#    'miles': 259.0,
#    'price': 1737.85,
#    'weight': 41144.0},
#   687: {'date': 1647302400, 'miles': 81.0, 'price': 587.93, 'weight': 5065.0},
#   688: {'date': 1644537600, 'miles': 336.97, 'price': 760.0, 'weight': 4000.0},
#   689: {'date': 1633478400,
#    'miles': 149.0,
#    'price': 876.97,
#    'weight': 40835.0},
#   690: {'date': 1626998400,
#    'miles': 122.0,
#    'price': 1110.01,
#    'weight': 40000.0},
#   691: {'date': 1660176000, 'miles': 17.0, 'price': 9.92, 'weight': 34962.0},
#   692: {'date': 1638230400,
#    'miles': 1429.1,
#    'price': 1887.0,
#    'weight': 40000.0},
#   693: {'date': 1653955200, 'miles': 190.1, 'price': 635.0, 'weight': 27910.0},
#   694: {'date': 1669766400,
#    'miles': 199.0,
#    'price': 971.82,
#    'weight': 24144.0},
#   695: {'date': 1633392000,
#    'miles': 328.0,
#    'price': 2020.94,
#    'weight': 40000.0},
#   696: {'date': 1621814400,
#    'miles': 1388.0,
#    'price': 7443.43,
#    'weight': 40000.0},
#   698: {'date': 1639699200, 'miles': 26.0, 'price': 10.67, 'weight': 45185.0},
#   699: {'date': 1644192000,
#    'miles': 1922.0,
#    'price': 4848.83,
#    'weight': 17407.0},
#   700: {'date': 1642118400,
#    'miles': 1953.6,
#    'price': 2772.0,
#    'weight': 43200.0},
#   701: {'date': 1619049600,
#    'miles': 1388.0,
#    'price': 4027.3,
#    'weight': 40000.0},
#   703: {'date': 1649721600,
#    'miles': 812.72,
#    'price': 1982.12,
#    'weight': 40000.0},
#   705: {'date': 1651708800,
#    'miles': 236.0,
#    'price': 972.62,
#    'weight': 20000.0},
#   706: {'date': 1643500800,
#    'miles': 54.72,
#    'price': 381.65,
#    'weight': 40000.0},
#   707: {'date': 1633046400,
#    'miles': 1485.0,
#    'price': 5347.64,
#    'weight': 39250.0},
#   708: {'date': 1629763200,
#    'miles': 705.0,
#    'price': 3325.58,
#    'weight': 42013.0},
#   709: {'date': 1621209600,
#    'miles': 291.0,
#    'price': 2103.41,
#    'weight': 24090.0},
#   712: {'date': 1626825600,
#    'miles': 324.04,
#    'price': 1140.0,
#    'weight': 35542.0},
#   713: {'date': 1613952000,
#    'miles': 1263.0,
#    'price': 3953.19,
#    'weight': 40000.0},
#   714: {'date': 1645401600,
#    'miles': 1901.0,
#    'price': 5716.03,
#    'weight': 18736.0},
#   715: {'date': 1645574400,
#    'miles': 867.5,
#    'price': 1860.0,
#    'weight': 40000.0},
#   716: {'date': 1644883200,
#    'miles': 800.0,
#    'price': 2900.0,
#    'weight': 39071.0},
#   717: {'date': 1627430400, 'miles': 29.0, 'price': 50.84, 'weight': 40000.0},
#   718: {'date': 1625702400,
#    'miles': 2136.0,
#    'price': 7371.86,
#    'weight': 40000.0},
#   720: {'date': 1667779200,
#    'miles': 621.6,
#    'price': 1950.41,
#    'weight': 44596.0},
#   721: {'date': 1624320000,
#    'miles': 1316.0,
#    'price': 4220.59,
#    'weight': 41400.0},
#   722: {'date': 1644105600,
#    'miles': 962.39,
#    'price': 2221.57,
#    'weight': 40000.0},
#   723: {'date': 1638835200,
#    'miles': 1099.18,
#    'price': 2605.65,
#    'weight': 40000.0},
#   724: {'date': 1624838400,
#    'miles': 1166.0,
#    'price': 4245.95,
#    'weight': 40000.0},
#   725: {'date': 1667520000, 'miles': 228.1, 'price': 600.0, 'weight': 43052.0},
#   729: {'date': 1633564800,
#    'miles': 800.0,
#    'price': 3100.0,
#    'weight': 32531.0},
#   730: {'date': 1649116800,
#    'miles': 1772.0,
#    'price': 4993.28,
#    'weight': 41400.0},
#   731: {'date': 1648166400,
#    'miles': 187.0,
#    'price': 596.53,
#    'weight': 48000.0},
#   732: {'date': 1635033600,
#    'miles': 2228.94,
#    'price': 3961.3,
#    'weight': 40000.0},
#   733: {'date': 1624579200,
#    'miles': 1024.0,
#    'price': 3788.25,
#    'weight': 40379.0},
#   734: {'date': 1663632000, 'miles': 11.0, 'price': 8.37, 'weight': 34289.0},
#   735: {'date': 1634083200, 'miles': 19.0, 'price': 135.03, 'weight': 40000.0},
#   736: {'date': 1647907200,
#    'miles': 926.98,
#    'price': 1429.92,
#    'weight': 40000.0},
#   737: {'date': 1643587200,
#    'miles': 467.0,
#    'price': 2243.99,
#    'weight': 41483.0},
#   738: {'date': 1650585600, 'miles': 79.0, 'price': 567.32, 'weight': 22176.0},
#   740: {'date': 1629763200,
#    'miles': 599.0,
#    'price': 2746.02,
#    'weight': 40865.0},
#   741: {'date': 1663718400, 'miles': 65.0, 'price': 641.06, 'weight': 40300.0},
#   743: {'date': 1664928000, 'miles': 348.0, 'price': 968.8, 'weight': 40556.0},
#   744: {'date': 1615852800, 'miles': 66.0, 'price': 96.97, 'weight': 40000.0},
#   746: {'date': 1646956800, 'miles': 18.6, 'price': 273.7, 'weight': 16.0},
#   747: {'date': 1650758400,
#    'miles': 558.6,
#    'price': 1873.27,
#    'weight': 37262.0},
#   750: {'date': 1645747200,
#    'miles': 839.0,
#    'price': 3260.44,
#    'weight': 36700.0},
#   751: {'date': 1645833600,
#    'miles': 2179.38,
#    'price': 4890.0,
#    'weight': 35000.0},
#   752: {'date': 1631059200, 'miles': 18.0, 'price': 111.74, 'weight': 40000.0},
#   753: {'date': 1641254400,
#    'miles': 676.0,
#    'price': 2347.93,
#    'weight': 43760.0},
#   754: {'date': 1631059200,
#    'miles': 1272.99,
#    'price': 3500.82,
#    'weight': 40000.0},
#   755: {'date': 1625011200,
#    'miles': 259.0,
#    'price': 1046.56,
#    'weight': 41647.0},
#   756: {'date': 1628899200,
#    'miles': 552.0,
#    'price': 1906.15,
#    'weight': 40116.0},
# ...
#   2865: {'date': 1642636800, 'miles': nan, 'price': 215.39, 'weight': 7000.0},
#   2874: {'date': 1619740800, 'miles': 320.0, 'price': nan, 'weight': nan},
#   2875: {'date': 1641945600, 'miles': 41.84, 'price': nan, 'weight': 40000.0},
#   2877: {'date': 1629158400, 'miles': nan, 'price': 9.46, 'weight': 1.0},
#   2878: {'date': 1653523200, 'miles': 132.0, 'price': 507.68, 'weight': 1.0},
#   2880: {'date': 1626739200,
#    'miles': nan,
#    'price': 1861.13,
#    'weight': 40000.0},
#   2882: {'date': 1650585600,
#    'miles': nan,
#    'price': 5034.69,
#    'weight': 40000.0},
#   2884: {'date': 1649721600,
#    'miles': nan,
#    'price': 5642.47,
#    'weight': 40000.0},
#   2886: {'date': 1626739200, 'miles': nan, 'price': 21.5, 'weight': 1.0},
#   2887: {'date': 1629072000,
#    'miles': nan,
#    'price': 1025.42,
#    'weight': 40000.0},
#   2892: {'date': 1653091200, 'miles': 17.0, 'price': 239.09, 'weight': 1.0},
#   2896: {'date': 1647475200, 'miles': nan, 'price': 596.6, 'weight': 31693.0},
#   2903: {'date': 1646352000, 'miles': 180.0, 'price': 0.0, 'weight': 32605.0},
#   2904: {'date': 1645574400, 'miles': nan, 'price': 25.14, 'weight': 1.0},
#   2907: {'date': 1640044800, 'miles': 24.0, 'price': nan, 'weight': 16437.0},
#   2909: {'date': 1629072000, 'miles': nan, 'price': 98.47, 'weight': 1.0},
#   2910: {'date': 1653523200, 'miles': 10.0, 'price': 233.7, 'weight': 1.0},
#   2917: {'date': 1646352000, 'miles': nan, 'price': 1117.4, 'weight': 1.0},
#   2919: {'date': 1655164800, 'miles': 610.0, 'price': 3674.94, 'weight': 1.0},
#   2926: {'date': 1621814400,
#    'miles': nan,
#    'price': 5341.07,
#    'weight': 40000.0},
#   2927: {'date': 1644796800,
#    'miles': nan,
#    'price': 5602.24,
#    'weight': 37130.0},
#   2934: {'date': 1644451200, 'miles': nan, 'price': 1750.0, 'weight': 23000.0},
#   2936: {'date': 1638835200, 'miles': nan, 'price': 762.75, 'weight': 3523.0},
#   2938: {'date': 1629849600, 'miles': nan, 'price': 0.01, 'weight': 40000.0},
#   2941: {'date': 1626825600,
#    'miles': nan,
#    'price': 1814.31,
#    'weight': 40000.0},
#   2945: {'date': 1621468800, 'miles': nan, 'price': 180.86, 'weight': 40000.0},
#   2946: {'date': 1640822400,
#    'miles': nan,
#    'price': 1223.19,
#    'weight': 40000.0},
#   2949: {'date': 1626912000,
#    'miles': nan,
#    'price': 1006.31,
#    'weight': 40000.0},
#   2951: {'date': 1641168000, 'miles': nan, 'price': 251.98, 'weight': 6875.0},
#   2954: {'date': 1633824000,
#    'miles': nan,
#    'price': 5411.25,
#    'weight': 40000.0},
#   2957: {'date': 1647302400, 'miles': nan, 'price': 25.14, 'weight': 1.0},
#   2964: {'date': 1649980800, 'miles': nan, 'price': 541.47, 'weight': 40000.0},
#   2965: {'date': 1645747200, 'miles': 246.0, 'price': 698.89, 'weight': 1.0},
#   2966: {'date': 1635292800, 'miles': nan, 'price': 926.83, 'weight': 40000.0},
#   2967: {'date': 1639699200, 'miles': nan, 'price': 3905.4, 'weight': 1.0},
#   2968: {'date': 1652659200, 'miles': 25.0, 'price': 313.5, 'weight': 1.0},
#   2969: {'date': 1634256000, 'miles': nan, 'price': nan, 'weight': 40000.0},
#   2972: {'date': 1635984000, 'miles': nan, 'price': 2619.5, 'weight': 8000.0},
#   2975: {'date': 1652227200, 'miles': 17.0, 'price': 285.0, 'weight': 1.0},
#   2977: {'date': 1648598400, 'miles': 101.39, 'price': nan, 'weight': 40000.0},
#   2981: {'date': 1643587200, 'miles': nan, 'price': 1345.0, 'weight': 15023.0},
#   2993: {'date': 1645747200, 'miles': 58.0, 'price': 802.58, 'weight': 1.0},
#   2994: {'date': 1613952000, 'miles': nan, 'price': nan, 'weight': 1.0},
#   2999: {'date': 1644796800, 'miles': nan, 'price': 5859.3, 'weight': 36680.0},
#   3001: {'date': 1644624000,
#    'miles': nan,
#    'price': 7296.46,
#    'weight': 40000.0},
#   3008: {'date': 1630368000,
#    'miles': nan,
#    'price': 1219.35,
#    'weight': 40000.0},
#   3012: {'date': 1642982400, 'miles': nan, 'price': 170.16, 'weight': 1.0},
#   3014: {'date': 1646006400,
#    'miles': nan,
#    'price': 1044.95,
#    'weight': 20930.0},
#   3015: {'date': 1637280000,
#    'miles': nan,
#    'price': 1430.94,
#    'weight': 40000.0},
#   3017: {'date': 1649721600, 'miles': nan, 'price': 2800.0, 'weight': 34144.0},
#   3018: {'date': 1627171200, 'miles': 144.0, 'price': nan, 'weight': 44125.0},
#   3020: {'date': 1634688000, 'miles': nan, 'price': nan, 'weight': 40000.0},
#   3028: {'date': 1648166400, 'miles': nan, 'price': 357.98, 'weight': 40000.0},
#   3029: {'date': 1641340800, 'miles': nan, 'price': 989.65, 'weight': 40000.0},
#   3043: {'date': 1641772800, 'miles': nan, 'price': nan, 'weight': 40000.0},
#   3045: {'date': 1641945600,
#    'miles': nan,
#    'price': 1563.36,
#    'weight': 40000.0},
#   3047: {'date': 1631577600, 'miles': nan, 'price': nan, 'weight': 40000.0},
#   3049: {'date': 1624838400, 'miles': nan, 'price': 802.34, 'weight': 40000.0},
#   3051: {'date': 1626307200,
#    'miles': nan,
#    'price': 1325.83,
#    'weight': 40000.0},
#   3054: {'date': 1645833600, 'miles': 21.0, 'price': 100.88, 'weight': 1.0},
#   3059: {'date': 1653004800, 'miles': 27.0, 'price': 276.67, 'weight': 1.0},
#   3061: {'date': 1643241600, 'miles': nan, 'price': 2764.54, 'weight': 4781.0},
#   3062: {'date': 1652832000, 'miles': 173.0, 'price': 872.94, 'weight': 1.0},
#   3070: {'date': 1613001600, 'miles': nan, 'price': nan, 'weight': 1.0},
#   3074: {'date': 1653264000, 'miles': 53.0, 'price': 654.56, 'weight': 1.0},
#   3078: {'date': 1630972800, 'miles': 289.68, 'price': nan, 'weight': 40000.0},
#   3088: {'date': 1627862400, 'miles': 154.0, 'price': nan, 'weight': 44320.0},
#   3093: {'date': 1646870400, 'miles': 614.0, 'price': 2117.34, 'weight': 1.0},
#   3094: {'date': 1652140800, 'miles': 122.0, 'price': 521.57, 'weight': 1.0},
#   3099: {'date': 1623196800, 'miles': nan, 'price': 548.38, 'weight': 40000.0},
#   3104: {'date': 1641859200, 'miles': nan, 'price': 1324.52, 'weight': 956.0},
#   3106: {'date': 1643068800, 'miles': nan, 'price': 2160.0, 'weight': 43892.0},
#   3107: {'date': 1634601600, 'miles': nan, 'price': 555.84, 'weight': 1.0},
#   3110: {'date': 1628121600, 'miles': nan, 'price': 712.39, 'weight': 40000.0},
#   3111: {'date': 1646006400, 'miles': 78.0, 'price': 413.46, 'weight': 1.0},
#   3114: {'date': 1623196800,
#    'miles': nan,
#    'price': 1321.43,
#    'weight': 40000.0},
#   3118: {'date': 1617753600, 'miles': 366.0, 'price': nan, 'weight': nan},
#   3125: {'date': 1636934400,
#    'miles': nan,
#    'price': 1222.47,
#    'weight': 40000.0},
#   3132: {'date': 1633219200, 'miles': nan, 'price': nan, 'weight': 40000.0},
#   3134: {'date': 1652918400, 'miles': 14.0, 'price': 346.86, 'weight': 1.0},
#   3142: {'date': 1651017600,
#    'miles': 1932.82,
#    'price': nan,
#    'weight': 40000.0},
#   3143: {'date': 1652918400, 'miles': 24.0, 'price': 244.48, 'weight': 1.0},
#   3148: {'date': 1646870400, 'miles': 18.0, 'price': 181.52, 'weight': 1.0},
#   3149: {'date': 1631750400, 'miles': 214.04, 'price': nan, 'weight': 40000.0},
#   3150: {'date': 1652140800, 'miles': 135.0, 'price': 526.8, 'weight': 1.0},
#   3157: {'date': 1649721600, 'miles': nan, 'price': 2757.59, 'weight': 5799.0},
#   3158: {'date': 1638748800, 'miles': nan, 'price': 53.92, 'weight': 1.0},
#   3159: {'date': 1637625600, 'miles': 93.34, 'price': nan, 'weight': 40000.0},
#   3161: {'date': 1640217600, 'miles': nan, 'price': 166.8, 'weight': 1.0},
#   3162: {'date': 1616112000, 'miles': nan, 'price': nan, 'weight': 1.0},
#   3163: {'date': 1627862400, 'miles': nan, 'price': 628.97, 'weight': 40000.0},
#   3165: {'date': 1629244800,
#    'miles': nan,
#    'price': 1753.99,
#    'weight': 40000.0},
#   3168: {'date': 1646697600, 'miles': 54.72, 'price': nan, 'weight': 40000.0},
#   3169: {'date': 1643241600, 'miles': nan, 'price': 375.0, 'weight': 25000.0},
#   3170: {'date': 1626825600, 'miles': 737.0, 'price': nan, 'weight': 44320.0},
#   3171: {'date': 1645401600, 'miles': nan, 'price': 810.16, 'weight': 2580.0},
#   3173: {'date': 1636675200, 'miles': 952.73, 'price': nan, 'weight': 40000.0},
#   3174: {'date': 1634169600, 'miles': nan, 'price': nan, 'weight': 40000.0},
#   3175: {'date': 1653004800, 'miles': 10.0, 'price': 125.03, 'weight': 1.0},
#   3180: {'date': 1652400000, 'miles': 15.0, 'price': 268.8, 'weight': 1.0},
#   3185: {'date': 1639440000, 'miles': nan, 'price': 346.94, 'weight': 10000.0},
#   3209: {'date': 1642550400, 'miles': nan, 'price': 756.22, 'weight': 40000.0},
#   3212: {'date': 1626912000, 'miles': 1787.0, 'price': nan, 'weight': 29523.0},
#   3213: {'date': 1629072000, 'miles': 14.0, 'price': nan, 'weight': 43988.0},
#   3215: {'date': 1622937600, 'miles': 90.0, 'price': nan, 'weight': nan},
#   3217: {'date': 1648771200,
#    'miles': nan,
#    'price': 5919.13,
#    'weight': 40000.0},
#   3225: {'date': 1652054400, 'miles': 34.0, 'price': 244.0, 'weight': 1.0},
#   3237: {'date': 1621814400,
#    'miles': nan,
#    'price': 1457.35,
#    'weight': 40000.0},
#   3239: {'date': 1625529600, 'miles': nan, 'price': 205.9, 'weight': 40000.0},
#   3243: {'date': 1652227200, 'miles': 5.0, 'price': 183.75, 'weight': 1.0},
#   3245: {'date': 1653350400, 'miles': 13.0, 'price': 300.35, 'weight': 1.0},
#   3253: {'date': 1635292800, 'miles': 54.72, 'price': nan, 'weight': 40000.0},
#   3254: {'date': 1644969600,
#    'miles': nan,
#    'price': 2253.18,
#    'weight': 15000.0},
#   3255: {'date': 1646006400, 'miles': 749.95, 'price': nan, 'weight': 40000.0},
#   3256: {'date': 1644796800, 'miles': nan, 'price': 2171.07, 'weight': 5000.0},
#   3257: {'date': 1645833600, 'miles': 5.0, 'price': 229.25, 'weight': 1.0},
#   3260: {'date': 1641427200,
#    'miles': nan,
#    'price': 5796.16,
#    'weight': 30564.0},
#   3273: {'date': 1647216000, 'miles': nan, 'price': 25.14, 'weight': 1.0},
#   3278: {'date': 1646956800, 'miles': nan, 'price': 5248.26, 'weight': 1.0},
#   3281: {'date': 1650412800,
#    'miles': nan,
#    'price': 2950.87,
#    'weight': 40000.0},
#   3283: {'date': 1640822400,
#    'miles': nan,
#    'price': 3744.17,
#    'weight': 35925.0},
#   3284: {'date': 1645660800, 'miles': nan, 'price': 1188.54, 'weight': 4000.0},
#   3290: {'date': 1653609600, 'miles': 33.0, 'price': 262.4, 'weight': 1.0},
#   3294: {'date': 1634688000,
#    'miles': nan,
#    'price': 1537.03,
#    'weight': 40000.0},
#   3305: {'date': 1645488000, 'miles': 24.0, 'price': nan, 'weight': 20763.0},
#   3311: {'date': 1646956800, 'miles': 59.0, 'price': 1782.69, 'weight': 1.0},
#   3316: {'date': 1634169600,
#    'miles': nan,
#    'price': 3568.67,
#    'weight': 40000.0},
#   3318: {'date': 1646697600, 'miles': 77.0, 'price': 558.17, 'weight': 1.0},
#   3322: {'date': 1646179200, 'miles': 133.58, 'price': nan, 'weight': 40000.0},
#   3324: {'date': 1652140800,
#    'miles': nan,
#    'price': 2023.36,
#    'weight': 40000.0},
#   3325: {'date': 1636329600, 'miles': nan, 'price': 5400.0, 'weight': 38240.0},
#   3329: {'date': 1639526400, 'miles': nan, 'price': nan, 'weight': 40000.0},
#   3338: {'date': 1646611200, 'miles': nan, 'price': 859.04, 'weight': 6136.0},
#   3342: {'date': 1623888000,
#    'miles': nan,
#    'price': 1154.49,
#    'weight': 40000.0},
#   3343: {'date': 1631923200, 'miles': 93.34, 'price': nan, 'weight': 40000.0},
#   3348: {'date': 1623456000, 'miles': nan, 'price': 291.49, 'weight': 40000.0},
#   3354: {'date': 1652832000, 'miles': 113.0, 'price': 939.89, 'weight': 1.0},
#   3355: {'date': 1652918400, 'miles': 123.0, 'price': 605.83, 'weight': 1.0},
#   3357: {'date': 1647216000,
#    'miles': nan,
#    'price': 3468.34,
#    'weight': 32974.0},
#   3364: {'date': 1642204800, 'miles': 54.72, 'price': nan, 'weight': 40000.0},
#   3365: {'date': 1639094400, 'miles': nan, 'price': nan, 'weight': 40000.0},
#   3366: {'date': 1644192000, 'miles': nan, 'price': 25.14, 'weight': 1.0},
#   3370: {'date': 1646524800, 'miles': 458.0, 'price': 2481.24, 'weight': 1.0},
#   3372: {'date': 1643328000, 'miles': nan, 'price': 5870.8, 'weight': 27124.0},
#   3373: {'date': 1634083200, 'miles': nan, 'price': 27.6, 'weight': 1.0},
#   3374: {'date': 1638835200, 'miles': 24.0, 'price': nan, 'weight': 19347.0},
#   3376: {'date': 1623715200,
#    'miles': nan,
#    'price': 2167.31,
#    'weight': 40000.0},
#   3378: {'date': 1649030400, 'miles': nan, 'price': 2592.0, 'weight': 42250.0},
#   3393: {'date': 1632182400, 'miles': nan, 'price': 517.82, 'weight': 40000.0},
#   3396: {'date': 1649203200, 'miles': nan, 'price': 2048.32, 'weight': 1193.0},
#   3399: {'date': 1653350400, 'miles': 20.0, 'price': 147.63, 'weight': 1.0},
#   3405: {'date': 1625184000,
#    'miles': nan,
#    'price': 1246.39,
#    'weight': 40000.0},
#   3414: {'date': 1652054400, 'miles': 58.0, 'price': 671.13, 'weight': 1.0},
#   3417: {'date': 1648512000,
#    'miles': nan,
#    'price': 5079.75,
#    'weight': 35507.0},
#   3419: {'date': 1653350400, 'miles': 11.0, 'price': 83.18, 'weight': 1.0},
#   3421: {'date': 1644796800, 'miles': nan, 'price': 899.05, 'weight': 40000.0},
#   3423: {'date': 1653004800, 'miles': 11.0, 'price': 365.01, 'weight': 1.0},
#   3426: {'date': 1633305600, 'miles': nan, 'price': nan, 'weight': 40000.0},
#   3431: {'date': 1617926400, 'miles': nan, 'price': 2075.0, 'weight': nan},
#   3440: {'date': 1644364800, 'miles': nan, 'price': 850.0, 'weight': 330.0},
#   3442: {'date': 1647216000, 'miles': 28.0, 'price': 423.63, 'weight': 1.0},
#   3443: {'date': 1636329600, 'miles': nan, 'price': nan, 'weight': 40000.0},
#   3447: {'date': 1635206400, 'miles': nan, 'price': 3263.0, 'weight': 40000.0},
#   3450: {'date': 1631577600, 'miles': nan, 'price': 205.91, 'weight': 40000.0},
#   3452: {'date': 1646870400, 'miles': 317.0, 'price': 1830.26, 'weight': 1.0},
#   3458: {'date': 1630454400, 'miles': nan, 'price': 89.79, 'weight': 40000.0},
#   3459: {'date': 1646870400, 'miles': nan, 'price': 25.14, 'weight': 1.0},
#   3460: {'date': 1647302400, 'miles': nan, 'price': 500.62, 'weight': 15000.0},
#   3461: {'date': 1645747200, 'miles': nan, 'price': 25.14, 'weight': 1.0},
#   3464: {'date': 1609977600, 'miles': 17.0, 'price': nan, 'weight': nan},
#   3469: {'date': 1653264000, 'miles': 116.0, 'price': 1379.5, 'weight': 1.0},
#   3474: {'date': 1651017600, 'miles': 102.5, 'price': nan, 'weight': 32203.0},
#   3478: {'date': 1646697600,
#    'miles': nan,
#    'price': 2285.14,
#    'weight': 15000.0},
#   3483: {'date': 1649376000, 'miles': nan, 'price': 821.61, 'weight': 38790.0},
#   3489: {'date': 1638144000,
#    'miles': nan,
#    'price': 1752.99,
#    'weight': 40000.0},
#   3492: {'date': 1642636800, 'miles': 144.84, 'price': nan, 'weight': 40000.0},
#   3495: {'date': 1639958400, 'miles': nan, 'price': 157.75, 'weight': 388.0},
#   3496: {'date': 1647216000, 'miles': nan, 'price': 98.25, 'weight': 860.0},
#   3498: {'date': 1638835200, 'miles': nan, 'price': 102.17, 'weight': 178.0},
#   3501: {'date': 1653091200, 'miles': 5.0, 'price': 58.66, 'weight': 1.0},
#   3506: {'date': 1633996800, 'miles': nan, 'price': 2193.3, 'weight': 40000.0},
#   3508: {'date': 1672358400, 'miles': 19.0, 'price': 0.0, 'weight': 25391.0},
#   3509: {'date': 1622592000, 'miles': nan, 'price': 691.44, 'weight': 40000.0},
#   3514: {'date': 1646006400, 'miles': 442.0, 'price': 1661.29, 'weight': 1.0},
#   3520: {'date': 1653004800, 'miles': 97.0, 'price': 430.83, 'weight': 1.0},
#   3528: {'date': 1627344000,
#    'miles': nan,
#    'price': 1322.09,
#    'weight': 40000.0},
#   3534: {'date': 1643328000, 'miles': nan, 'price': 49.18, 'weight': 1.0},
#   3536: {'date': 1643760000, 'miles': 93.34, 'price': nan, 'weight': 40000.0},
#   3541: {'date': 1638403200,
#    'miles': 1158.73,
#    'price': nan,
#    'weight': 40000.0},
#   3542: {'date': 1643155200, 'miles': nan, 'price': 3100.0, 'weight': 4950.0},
#   3548: {'date': 1634515200, 'miles': nan, 'price': 0.01, 'weight': 40000.0},
#   3549: {'date': 1632096000,
#    'miles': nan,
#    'price': 2695.24,
#    'weight': 40000.0},
#   3551: {'date': 1634860800,
#    'miles': nan,
#    'price': 4330.98,
#    'weight': 40000.0},
#   3554: {'date': 1626220800,
#    'miles': nan,
#    'price': 2251.74,
#    'weight': 40000.0},
#   3559: {'date': 1643241600, 'miles': nan, 'price': nan, 'weight': 40000.0},
#   3564: {'date': 1643932800, 'miles': nan, 'price': 865.69, 'weight': 40000.0},
#   3565: {'date': 1643760000,
#    'miles': nan,
#    'price': 3170.98,
#    'weight': 37365.0},
#   3568: {'date': 1643155200, 'miles': nan, 'price': nan, 'weight': 40000.0},
#   ...})

# %% [markdown]
# ### Assignment
#
# **Your task is to refactor the `validator` function to catch outliers in the API response.**
#
# Your solution should meet the following criteria:
# * It should use _only_ the Python standard library (no Pandas or other third-party libraries—though you can use whatever you want for data exploration)
# * Running the cell below should return a `tuple` containing two objects:
#     1. a `dict` of valid shipment data (the definition of "valid" is up to you)
#     2. a `dict` of invalid shipment data
# * It should be structured such that we could reuse `validator` in other pipelines without altering the internal logic of the function itself.
#
# Beyond these requirements, use your best judgment and be prepared to explain any assumptions or decisions you made. Everything you need is in this document. Your time is limited, so prioritize accordingly.
#
# **You have 75 minutes from receipt of this file to complete as much as possible. When time is up, send us what you have so far. Good luck!**

# %% [markdown]
# ### Figuring out the solution below

# %%
# Need to visualise the data
import pandas as pd

# %%
temp_df = pd.read_json("leaf_dataops.json")

# %%
temp_df
# Out:
#             date    miles    price   weight
# 0     2022-04-20   571.80  1045.00  37601.0
# 1     2021-02-18  1110.00      NaN      NaN
# 2     2022-03-23      NaN  2475.26  40000.0
# 3     2022-03-16     9.00    11.11      1.0
# 4     2022-03-25      NaN  1200.00    222.0
# ...          ...      ...      ...      ...
# 99995 2022-05-17    36.00   196.85      1.0
# 99996 2022-05-10    30.00   187.86      1.0
# 99997 2021-06-18    66.00   177.98  40000.0
# 99998 2021-09-13   214.04      NaN  40000.0
# 99999 2022-03-08      NaN      NaN  40000.0
#
# [100000 rows x 4 columns]

# %%
#pandas has parsed the date into something readable
# Noticing that there are a few NaN values scattered in the miles, price, and weight columns

# %%
temp_df.shape
# Out:
# (100000, 4)

# %%
temp_df.isna().sum()
# Out:
# date          0
# miles     17564
# price      6626
# weight      705
# dtype: int64

# %%
min(temp_df.date)
# Out:
# Timestamp('2021-01-01 00:00:00')

# %%
max(temp_df.date)
# Out:
# Timestamp('2032-02-20 05:20:00')

# %%
from json import loads
from functools import reduce
from math import isnan


def pipeline(*objects):
    return reduce(lambda x, fn: fn(x), objects)


def mock_api_request(url: str) -> str:
    with open("leaf_dataops.json", "r") as f:
        return f.read()


def parse_json(json: str) -> dict:
    return loads(json)

def validator(data: dict, rules: dict = None) -> tuple:
    # dicts for valid and invalid_data
    
    valid_data = {}
    invalid_data = {}

    
    # Max Values
    max_miles = max(data['miles'])
    max_price = max(data['price'])
    max_weight = max(data['weight'])
    
    # Min Values
    min_miles = min(data['miles'])
    min_price = min(data['price'])
    min_weight = min(data['weight'])
    

    for i, _ in enumerate(data['date']):
        valid = True
        for key in data.keys():
            
            value = data[key][i]
            
            if key == 'date':
                if not isinstance(value, int):
                    valid = False
                    break
            elif key == 'miles' or key == 'price' or key == 'weight':
                if key == 'miles' and (value <= 0 or value > max_miles or isnan(value)):
                    valid = False
                    break
                if key == 'price' and (value <= 0 or value > max_price or isnan(value)):
                    valid = False
                    break
                if key == 'weight' and (value <= 0 or value > max_weight or isnan(value)):
                    valid = False
                    break
                

        if valid:
            valid_data[i] = {k: data[k][i] for k in data.keys()}
        else:
            invalid_data[i] = {k: data[k][i] for k in data.keys()}
    
    return valid_data, invalid_data


val, inval = pipeline(
    mock_api_request("www.shipper.com/api?min_date=20210101&max_date=20221231"),
    parse_json,
    validator,
)

len(val), len(inval)
# Out:
# (78473, 21527)
